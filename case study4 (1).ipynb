# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as snc
import scipy.stats as stats

# %%
df=pd.read_csv("Sales_add.csv")
df
# Out:
#        Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0    Month-1  Region - A  Manager - A                          132921
# 1    Month-2  Region - A  Manager - C                          149559
# 2    Month-3  Region - B  Manager - A                          146278
# 3    Month-4  Region - B  Manager - B                          152167
# 4    Month-5  Region - C  Manager - B                          159525
# 5    Month-6  Region - A  Manager - B                          137163
# 6    Month-7  Region - C  Manager - C                          130625
# 7    Month-8  Region - A  Manager - A                          131140
# 8    Month-9  Region - B  Manager - C                          171259
# 9   Month-10  Region - C  Manager - B                          141956
# 10  Month-11  Region - B  Manager - C                          159339
# 11  Month-12  Region - A  Manager - A                          178939
# 12  Month-13  Region - B  Manager - A                          145062
# 13  Month-14  Region - A  Manager - A                          151514
# 14  Month-15  Region - C  Manager - A                          147463
# 15  Month-16  Region - A  Manager - B                          177195
# 16  Month-17  Region - A  Manager - C                          140862
# 17  Month-18  Region - C  Manager - B                          167996
# 18  Month-19  Region - B  Manager - A                          132135
# 19  Month-20  Region - A  Manager - B                          152493
# 20  Month-21  Region - B  Manager - A                          147425
# 21  Month-22  Region - A  Manager - C                          130263
#
#     Sales_After_digital_add(in $)
# 0                          270390
# 1                          223334
# 2                          244243
# 3                          231808
# 4                          258402
# 5                          256948
# 6                          222106
# 7                          230637
# 8                          226261
# 9                          193735
# 10                         203175
# 11                         276279
# 12                         205180
# 13                         253131
# 14                         229336
# 15                         187305
# 16                         234908
# 17                         191517
# 18                         227040
# 19                         212579
# 20                         263388
# 21                         243020

# %%
df.head()
# Out:
#      Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0  Month-1  Region - A  Manager - A                          132921
# 1  Month-2  Region - A  Manager - C                          149559
# 2  Month-3  Region - B  Manager - A                          146278
# 3  Month-4  Region - B  Manager - B                          152167
# 4  Month-5  Region - C  Manager - B                          159525
#
#    Sales_After_digital_add(in $)
# 0                         270390
# 1                         223334
# 2                         244243
# 3                         231808
# 4                         258402

# %%
df.mean()
# Out:
# Sales_before_digital_add(in $)    149239.954545
# Sales_After_digital_add(in $)     231123.727273
# dtype: float64

# %%
#The company wishes to clarify whether there is any increase in sales after stepping into digital marketing.

# %%
usedsalesdf.sales groupby(usedsalesdf.salesbefore).mean()
salesbefore=usedsalesdf[usedsalesdf.salestype=='salesbefore']
salesafter=usedsalesdf[usedsalesdf.salestype=='salesafter']
from scipy.stats import ttest_ind
ttest_ind(salesbefore,salesafter,equal_var=False)
# Out:
#   File "<ipython-input-13-c5c8502fa0ff>", line 1
#     usedsalesdf.sales groupby(usedsalesdf.salesbefore).mean()
#                       ^
# SyntaxError: invalid syntax

# %%
test_prep=df[df['Sales_After_digital_add(in $)']=='increase']
test_prep=test_prep.drop(['Sales_After_digital_add(in $)'],'sales',axis=1)
no_test_prep=df[df['Sales_After_digital_add(in $)']=='none']
no_test_prep=no_test_prep.drop(['Sales_After_digital_add(in $)','Sales'],axis=1)
test_prep
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-271c349d0057> in <module>
#       1 test_prep=df[df['Sales_After_digital_add(in $)']=='increase']
# ----> 2 test_prep=test_prep.drop(['Sales_After_digital_add(in $)'],'sales',axis=1)
#       3 no_test_prep=df[df['Sales_After_digital_add(in $)']=='none']
#       4 no_test_prep=no_test_prep.drop(['Sales_After_digital_add(in $)','Sales'],axis=1)
#       5 test_prep
#
# TypeError: drop() got multiple values for argument 'axis'

# %%
Sales_After_digital_add(in $ = df[df['sales']=='Sales_After_digital_add(in $']
Sales_After_digital_add(in $
# Out:
#   File "<ipython-input-17-7b80840b1f40>", line 1
#     Sales_After_digital_add(in $ = df[df['sales']=='Sales_After_digital_add(in $']
#                             ^
# SyntaxError: invalid syntax

# %%
df.columns
# Out:
# Index(['Month', 'Region', 'Manager', 'Sales_before_digital_add(in $)',
#        'Sales_After_digital_add(in $)'],
#       dtype='object')

# %%
Sales_before_digital_add(in $) = df[df['sales'] == 'Sales_before_digital_add(in $)']
Sales_before_digital_add(in $)
# Out:
#   File "<ipython-input-24-d88bde63e2ec>", line 1
#     Sales_before_digital_add(in $) = df[df['sales'] == 'Sales_before_digital_add(in $)']
#                              ^
# SyntaxError: invalid syntax

# %%
df.Sales_before_digital_add(in $)
# Out:
#   File "<ipython-input-25-7ae713e6cd96>", line 1
#     df.Sales_before_digital_add(in $)
#                                 ^
# SyntaxError: invalid syntax

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Month                           22 non-null     object
#  1   Region                          22 non-null     object
#  2   Manager                         22 non-null     object
#  3   Sales_before_digital_add(in $)  22 non-null     int64
#  4   Sales_After_digital_add(in $)   22 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 1008.0+ bytes

# %%
sales_before_add = df['Sales_before_digital_add(in $)']
sales_after_add = df['Sales_After_digital_add(in $)']

# %%
tvalue,pvalue = stats.ttest_ind(sales_before_add,sales_after_add)

# %%
stats.ttest_ind(sales_before_add,sales_after_add)
# Out:
# Ttest_indResult(statistic=-12.995084451110877, pvalue=2.614368006904645e-16)

# %%
tcriteria = stats.t.ppf(1-0.05,40)
stats.t.ppf(1-0.05,40)
# Out:
# 1.68385101138658

# %%
if (tvalue>tcriteria and pvalue <0.05):
    print('Reject H0:There is increase in sales after starting digital marketing')
else:
    print('Reject H1:There is no increase in sales after starting digital marketing')
# Out:
# Reject H1:There is no increase in sales after starting digital marketing

# %% [markdown]
# **So We can conclude that there is a hike in sales after starting digital marketing**

# %% [markdown]
# # 2 The company needs to check whether there is any dependency between the features Region and Manager

# %%
df1=df.groupby('Region')['Manager'].value_counts().unstack()

# %%
df1
# Out:
# Manager     Manager - A  Manager - B  Manager - C
# Region
# Region - A            4            3            3
# Region - B            4            1            2
# Region - C            1            3            1

# %%
chivalue,pvalue,df,expvalues=stats.chi2_contingency(df1)

# %%
print('Chi sqaure Test Statistic:',chivalue)
print('Pvalue of test data;',pvalue)
print('Degrees of Freedom:',df)
print('Expected observations of data:',expvalues)
# Out:
# Chi sqaure Test Statistic: 3.050566893424036
# Pvalue of test data; 0.5493991051158094
# Degrees of Freedom: 4
# Expected observations of data: [[4.09090909 3.18181818 2.72727273]
#  [2.86363636 2.22727273 1.90909091]
#  [2.04545455 1.59090909 1.36363636]]

# %%
chicriteria=stats.chi2.ppf(1-0.05,4)
stats.chi2.ppf(1-0.05,df=4)
# Out:
# 9.487729036781154

# %%
if(chivalue>chicriteria and pvalue<0.05):
    print('reject H0: Region and Manager features are independent')
else:
    print('reject H1: Region and Manager features are dependent')
# Out:
# reject H1: Region and Manager features are dependent

# %% [markdown]
# **Finaly  the Chi square test for independence the Features Region and Manager are not dependent**
